# %% [markdown]
# **Jet Engine**

# %%
import pandas as pd

# %%
# Read dataset files and convert to dataframes
data = pd.read_csv("/content/train_FD004.txt", sep=" ", header=None)

# %%
# Show dataset dimension
print("Shape of data :", data.shape)

# Show initial data
data
# Out:
# Shape of data : (61249, 28)
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  42.0049  0.8400  100.0  445.00  549.68  1343.43  1112.93
# 1        1    2  20.0020  0.7002  100.0  491.19  606.07  1477.61  1237.50
# 2        1    3  42.0038  0.8409  100.0  445.00  548.95  1343.12  1117.05
# 3        1    4  42.0000  0.8400  100.0  445.00  548.70  1341.24  1118.03
# 4        1    5  25.0063  0.6207   60.0  462.54  536.10  1255.23  1033.59
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 61244  249  251   9.9998  0.2500  100.0  489.05  605.33  1516.36  1315.28
# 61245  249  252   0.0028  0.0015  100.0  518.67  643.42  1598.92  1426.77
# 61246  249  253   0.0029  0.0000  100.0  518.67  643.68  1607.72  1430.56
# 61247  249  254  35.0046  0.8400  100.0  449.44  555.77  1381.29  1148.18
# 61248  249  255  42.0030  0.8400  100.0  445.00  549.85  1369.75  1147.45
#
#           9   ...       18       19    20   21    22      23     24       25  \
# 0       3.91  ...  8074.83   9.3335  0.02  330  2212  100.00  10.62   6.3670
# 1       9.35  ...  8046.13   9.1913  0.02  361  2324  100.00  24.37  14.6552
# 2       3.91  ...  8066.62   9.4007  0.02  329  2212  100.00  10.48   6.4213
# 3       3.91  ...  8076.05   9.3369  0.02  328  2212  100.00  10.54   6.4176
# 4       7.05  ...  7865.80  10.8366  0.02  305  1915   84.93  14.03   8.6754
# ...      ...  ...      ...      ...   ...  ...   ...     ...    ...      ...
# 61244  10.52  ...  8185.69   8.4541  0.03  372  2319  100.00  29.11  17.5234
# 61245  14.62  ...  8185.47   8.2221  0.03  396  2388  100.00  39.38  23.7151
# 61246  14.62  ...  8193.94   8.2525  0.03  395  2388  100.00  39.78  23.8270
# 61247   5.48  ...  8125.64   9.0515  0.02  337  2223  100.00  15.26   9.0774
# 61248   3.91  ...  8144.33   9.1207  0.02  333  2212  100.00  10.66   6.4341
#
#        26  27
# 0     NaN NaN
# 1     NaN NaN
# 2     NaN NaN
# 3     NaN NaN
# 4     NaN NaN
# ...    ..  ..
# 61244 NaN NaN
# 61245 NaN NaN
# 61246 NaN NaN
# 61247 NaN NaN
# 61248 NaN NaN
#
# [61249 rows x 28 columns]

# %%
# Remove NaN values from the last 2 columns of the dataset
data.drop(columns=[26, 27], inplace=True)

# List the column names according to the dataset description
columns = [
    'engine', 'cycle', 'setting1', 'setting2', 'setting3', 'sensor1',
    'sensor2', 'sensor3', 'sensor4', 'sensor5', 'sensor6', 'sensor7',
    'sensor8', 'sensor9', 'sensor10', 'sensor11', 'sensor12', 'sensor13',
    'sensor14', 'sensor15', 'sensor16', 'sensor17', 'sensor18', 'sensor19',
    'sensor20', 'sensor21'
]

# Rename a column in the dataset
data.columns = columns

# %%
# Melihat statistik dari dataset
data.describe().transpose()
# Out:
#             count         mean         std        min        25%        50%  \
# engine    61249.0   124.325181   71.995350     1.0000    60.0000   126.0000
# cycle     61249.0   134.311417   89.783389     1.0000    62.0000   123.0000
# setting1  61249.0    23.999823   14.780722     0.0000    10.0046    25.0014
# setting2  61249.0     0.571347    0.310703     0.0000     0.2507     0.7000
# setting3  61249.0    94.031576   14.251954    60.0000   100.0000   100.0000
# sensor1   61249.0   472.882435   26.436832   445.0000   445.0000   462.5400
# sensor2   61249.0   579.420056   37.342647   535.4800   549.3300   555.7400
# sensor3   61249.0  1417.896600  106.167598  1242.6700  1350.5500  1367.6800
# sensor4   61249.0  1201.915359  119.327591  1024.4200  1119.4900  1136.9200
# sensor5   61249.0     8.031626    3.622872     3.9100     3.9100     7.0500
# sensor6   61249.0    11.589457    5.444017     5.6700     5.7200     9.0300
# sensor7   61249.0   283.328633  146.880210   136.1700   142.9200   194.9600
# sensor8   61249.0  2228.686034  145.348243  1914.7200  2211.9500  2223.0700
# sensor9   61249.0  8524.673301  336.927547  7984.5100  8320.5900  8362.7600
# sensor10  61249.0     1.096445    0.127681     0.9300     1.0200     1.0300
# sensor11  61249.0    42.874529    3.243492    36.0400    41.7600    42.3300
# sensor12  61249.0   266.735665  138.479109   128.3100   134.5200   183.4500
# sensor13  61249.0  2334.427590  128.197859  2027.5700  2387.9100  2388.0600
# sensor14  61249.0  8067.811812   85.670543  7845.7800  8062.6300  8083.8100
# sensor15  61249.0     9.285604    0.750374     8.1757     8.6480     9.2556
# sensor16  61249.0     0.023252    0.004685     0.0200     0.0200     0.0200
# sensor17  61249.0   347.760029   27.808283   302.0000   330.0000   334.0000
# sensor18  61249.0  2228.613283  145.472491  1915.0000  2212.0000  2223.0000
# sensor19  61249.0    97.751396    5.369424    84.9300   100.0000   100.0000
# sensor20  61249.0    20.864333    9.936396    10.1600    10.9400    14.9300
# sensor21  61249.0    12.518995    5.962697     6.0843     6.5661     8.9601
#
#                 75%        max
# engine     185.0000   249.0000
# cycle      191.0000   543.0000
# setting1    41.9981    42.0080
# setting2     0.8400     0.8420
# setting3   100.0000   100.0000
# sensor1    491.1900   518.6700
# sensor2    607.0700   644.4200
# sensor3   1497.4200  1613.0000
# sensor4   1302.6200  1440.7700
# sensor5     10.5200    14.6200
# sensor6     15.4800    21.6100
# sensor7    394.2800   570.8100
# sensor8   2323.9300  2388.6400
# sensor9   8777.2500  9196.8100
# sensor10     1.2600     1.3200
# sensor11    45.2200    48.3600
# sensor12   371.4000   537.4900
# sensor13  2388.1700  2390.4900
# sensor14  8128.3500  8261.6500
# sensor15     9.3658    11.0663
# sensor16     0.0300     0.0300
# sensor17   368.0000   399.0000
# sensor18  2324.0000  2388.0000
# sensor19   100.0000   100.0000
# sensor20    28.5600    39.8900
# sensor21    17.1355    23.8852

# %%
def assign_label(data, threshold):
    '''
    Function:
        - Labeling a dataset
    Args:
        - data -> dataset to be labeled
        - threshold -> threshold value of cycle before failure
    Return:
        - data -> labeled dataset
    '''

    for i in range(1, 101):
        # Get max cycle each engine
        max_cycle = data.loc[(data['engine'] == i), 'cycle'].max()

        # Determine when cycle is labeled as failure
        start_warning = max_cycle - threshold

        # Assign label 1 to dataset
        data.loc[(data['engine'] == i) & (data['cycle'] > start_warning), 'status'] = 1

    # Assign label 0 to dataset
    data['status'].fillna(0, inplace=True)

    # Return labeled dataset
    return data


# Determine the threshold value
threshold = 20

# Call assign_label function to get label
data = assign_label(data, threshold)

# Show data after labelling
data
# Out:
# <ipython-input-14-26f280e9f6ed>:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['status'].fillna(0, inplace=True)
#        engine  cycle  setting1  setting2  setting3  sensor1  sensor2  sensor3  \
# 0           1      1   42.0049    0.8400     100.0   445.00   549.68  1343.43
# 1           1      2   20.0020    0.7002     100.0   491.19   606.07  1477.61
# 2           1      3   42.0038    0.8409     100.0   445.00   548.95  1343.12
# 3           1      4   42.0000    0.8400     100.0   445.00   548.70  1341.24
# 4           1      5   25.0063    0.6207      60.0   462.54   536.10  1255.23
# ...       ...    ...       ...       ...       ...      ...      ...      ...
# 61244     249    251    9.9998    0.2500     100.0   489.05   605.33  1516.36
# 61245     249    252    0.0028    0.0015     100.0   518.67   643.42  1598.92
# 61246     249    253    0.0029    0.0000     100.0   518.67   643.68  1607.72
# 61247     249    254   35.0046    0.8400     100.0   449.44   555.77  1381.29
# 61248     249    255   42.0030    0.8400     100.0   445.00   549.85  1369.75
#
#        sensor4  sensor5  ...  sensor13  sensor14  sensor15  sensor16  \
# 0      1112.93     3.91  ...   2387.99   8074.83    9.3335      0.02
# 1      1237.50     9.35  ...   2387.73   8046.13    9.1913      0.02
# 2      1117.05     3.91  ...   2387.97   8066.62    9.4007      0.02
# 3      1118.03     3.91  ...   2388.02   8076.05    9.3369      0.02
# 4      1033.59     7.05  ...   2028.08   7865.80   10.8366      0.02
# ...        ...      ...  ...       ...       ...       ...       ...
# 61244  1315.28    10.52  ...   2388.73   8185.69    8.4541      0.03
# 61245  1426.77    14.62  ...   2388.46   8185.47    8.2221      0.03
# 61246  1430.56    14.62  ...   2388.48   8193.94    8.2525      0.03
# 61247  1148.18     5.48  ...   2388.83   8125.64    9.0515      0.02
# 61248  1147.45     3.91  ...   2388.66   8144.33    9.1207      0.02
#
#        sensor17  sensor18  sensor19  sensor20  sensor21  status
# 0           330      2212    100.00     10.62    6.3670     0.0
# 1           361      2324    100.00     24.37   14.6552     0.0
# 2           329      2212    100.00     10.48    6.4213     0.0
# 3           328      2212    100.00     10.54    6.4176     0.0
# 4           305      1915     84.93     14.03    8.6754     0.0
# ...         ...       ...       ...       ...       ...     ...
# 61244       372      2319    100.00     29.11   17.5234     0.0
# 61245       396      2388    100.00     39.38   23.7151     0.0
# 61246       395      2388    100.00     39.78   23.8270     0.0
# 61247       337      2223    100.00     15.26    9.0774     0.0
# 61248       333      2212    100.00     10.66    6.4341     0.0
#
# [61249 rows x 27 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Heatmap for checking the correlation
threshold = 0.2
plt.figure(figsize=(12, 10))
sns.set(font_scale=0.7)
sns.set_style("whitegrid", {"axes.facecolor": ".0"})

cluster = data.corr()
mask = cluster.where((abs(cluster) >= threshold)).isna()
plot_kws={"s": 1}
sns.heatmap(cluster,
            cmap='RdYlBu',
            annot=True,
            mask=mask,
            linewidths=0.2,
            linecolor='lightgrey').set_facecolor('white')
plt.title("Feature Correlation using Heatmap")
# Heatmap for checking the correlation
threshold = 0.2
plt.figure(figsize=(12, 10))
sns.set(font_scale=0.7)
sns.set_style("whitegrid", {"axes.facecolor": ".0"})

cluster = data.corr()
mask = cluster.where((abs(cluster) >= threshold)).isna()
plot_kws={"s": 1}
sns.heatmap(cluster,
            cmap='RdYlBu',
            annot=True,
            mask=mask,
            linewidths=0.2,
            linecolor='lightgrey').set_facecolor('white')
plt.title("Feature Correlation using Heatmap")
# Out:
# Text(0.5, 1.0, 'Feature Correlation using Heatmap')

# %%
# Show predictor that have correlation value >= threshold
correlation = data.corr()
relevant_features = correlation[abs(correlation['status']) >= threshold]
relevant_features['status']

# Keep a relevant features (correlation value >= threshold)
list_relevant_features = list(relevant_features.index[1:])

# Applying feature selection
data = data[list_relevant_features]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# Determine predictor (X) and target (y)
X = data.iloc[:,:-1]
y = data.iloc[:,-1:]

# Split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Change y_train into 1 dimension form
y_train = y_train.squeeze()

# %%
# Check dimension of data train and test
print("Shape of train : ", X_train.shape)
print("Shape of test  : ", X_test.shape)
# Out:
# Shape of train :  (48999, 0)
# Shape of test  :  (12250, 0)

# %%
# Change X_train to dataframe
X_train = pd.DataFrame(X_train, columns = X.columns)

# Scaling process
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Show data after scaling process
X_train_scaling = pd.DataFrame(X_train, columns = X.columns)
X_train_scaling
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-cc4526f46d00> in <cell line: 0>()
#       4 # Scaling process
#       5 scaler = StandardScaler()
# ----> 6 X_train = scaler.fit_transform(X_train)
#       7 X_test = scaler.transform(X_test)
#       8
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
#     920             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#     895
#     896     @_fit_context(prefer_skip_nested_validation=True)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     928         """
#     929         first_call = not hasattr(self, "n_samples_seen_")
# --> 930         X = validate_data(
#     931             self,
#     932             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929         )
#     930         if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 931             dtype_orig = np.result_type(*dtypes_orig)
#     932         elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     933             # Force object if any of the dtypes is an object
#
# ValueError: at least one array or dtype is required

# %%
# Import library to build neural network architecture
from keras.layers import Dense, LeakyReLU
from keras.models import Sequential

# Import library for optimization
from keras.optimizers import Adam

# Import library to prevent overfitting
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

# Build neural network architecture
model = Sequential()
model.add(Dense(512, input_dim=X_train.shape[1], activation = LeakyReLU(), kernel_regularizer=l2(0.01)))
model.add(Dense(256, activation = LeakyReLU(), kernel_regularizer=l2(0.01)))
model.add(Dense(128, activation = LeakyReLU(), kernel_regularizer=l2(0.01)))
model.add(Dense(1, activation = 'sigmoid'))

opt = Adam(learning_rate = 0.0001) # optimizer
model.compile(optimizer = opt,
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

# Create a object from EarlyStopping class
earlystopper = EarlyStopping(
    monitor = 'val_loss',
    min_delta = 0,
    patience = 5,
    verbose= 1)

# Fitting network
history = model.fit(
    X_train,
    y_train,
    epochs = 200,
    batch_size = 128,
    validation_split = 0.20,
    verbose = 1,
    callbacks = [earlystopper])

history_dict = history.history
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9691 - loss: 4.7327 - val_accuracy: 0.9643 - val_loss: 2.2637
# Epoch 2/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9676 - loss: 1.8136 - val_accuracy: 0.9643 - val_loss: 0.8959
# Epoch 3/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9673 - loss: 0.7293 - val_accuracy: 0.9643 - val_loss: 0.4064
# Epoch 4/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9681 - loss: 0.3409 - val_accuracy: 0.9643 - val_loss: 0.2402
# Epoch 5/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9679 - loss: 0.2119 - val_accuracy: 0.9643 - val_loss: 0.1865
# Epoch 6/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9675 - loss: 0.1712 - val_accuracy: 0.9643 - val_loss: 0.1693
# Epoch 7/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9674 - loss: 0.1579 - val_accuracy: 0.9643 - val_loss: 0.1634
# Epoch 8/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9670 - loss: 0.1539 - val_accuracy: 0.9643 - val_loss: 0.1605
# Epoch 9/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9680 - loss: 0.1486 - val_accuracy: 0.9643 - val_loss: 0.1591
# Epoch 10/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9663 - loss: 0.1523 - val_accuracy: 0.9643 - val_loss: 0.1588
# Epoch 11/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9674 - loss: 0.1478 - val_accuracy: 0.9643 - val_loss: 0.1570
# Epoch 12/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9677 - loss: 0.1461 - val_accuracy: 0.9643 - val_loss: 0.1568
# Epoch 13/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9681 - loss: 0.1439 - val_accuracy: 0.9643 - val_loss: 0.1558
# Epoch 14/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9681 - loss: 0.1435 - val_accuracy: 0.9643 - val_loss: 0.1555
# Epoch 15/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9673 - loss: 0.1457 - val_accuracy: 0.9643 - val_loss: 0.1552
# Epoch 16/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9679 - loss: 0.1433 - val_accuracy: 0.9643 - val_loss: 0.1551
# Epoch 17/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9661 - loss: 0.1490 - val_accuracy: 0.9643 - val_loss: 0.1552
# Epoch 18/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9680 - loss: 0.1426 - val_accuracy: 0.9643 - val_loss: 0.1548
# Epoch 19/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9680 - loss: 0.1423 - val_accuracy: 0.9643 - val_loss: 0.1545
# Epoch 20/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9657 - loss: 0.1496 - val_accuracy: 0.9643 - val_loss: 0.1544
# Epoch 21/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9695 - loss: 0.1370 - val_accuracy: 0.9643 - val_loss: 0.1543
# Epoch 22/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9678 - loss: 0.1430 - val_accuracy: 0.9643 - val_loss: 0.1543
# Epoch 23/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9677 - loss: 0.1429 - val_accuracy: 0.9643 - val_loss: 0.1556
# Epoch 24/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9685 - loss: 0.1403 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 25/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9680 - loss: 0.1419 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 26/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9696 - loss: 0.1366 - val_accuracy: 0.9643 - val_loss: 0.1543
# Epoch 27/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9681 - loss: 0.1416 - val_accuracy: 0.9643 - val_loss: 0.1546
# Epoch 28/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9682 - loss: 0.1414 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 29/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9683 - loss: 0.1408 - val_accuracy: 0.9643 - val_loss: 0.1541
# Epoch 30/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9678 - loss: 0.1426 - val_accuracy: 0.9643 - val_loss: 0.1541
# Epoch 31/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9681 - loss: 0.1416 - val_accuracy: 0.9643 - val_loss: 0.1541
# Epoch 32/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9688 - loss: 0.1391 - val_accuracy: 0.9643 - val_loss: 0.1546
# Epoch 33/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9671 - loss: 0.1448 - val_accuracy: 0.9643 - val_loss: 0.1543
# Epoch 34/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9684 - loss: 0.1405 - val_accuracy: 0.9643 - val_loss: 0.1544
# Epoch 35/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9672 - loss: 0.1444 - val_accuracy: 0.9643 - val_loss: 0.1541
# Epoch 36/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9676 - loss: 0.1432 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 37/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9687 - loss: 0.1393 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 38/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9690 - loss: 0.1385 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 39/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9674 - loss: 0.1438 - val_accuracy: 0.9643 - val_loss: 0.1543
# Epoch 40/200
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9684 - loss: 0.1403 - val_accuracy: 0.9643 - val_loss: 0.1542
# Epoch 40: early stopping

# %%
# Predicting test data
y_predict = (model.predict(X_test) > 0.5).astype('int32')

# Show confusion matrix table
matrix = metrics.confusion_matrix(y_test, y_predict)
matrix_display = metrics.ConfusionMatrixDisplay(confusion_matrix = matrix, display_labels = ["normal", "failure"])
matrix_display.plot()
plt.grid(False)
plt.show()
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_predict))
print("Precision:", metrics.precision_score(y_test, y_predict))
print("Recall:", metrics.recall_score(y_test, y_predict))
print("F1 Score:", metrics.f1_score(y_test, y_predict))
# Out:
# Accuracy: 0.9760116307244973
# Precision: 0.8909090909090909
# Recall: 0.8235294117647058
# F1 Score: 0.8558951965065502

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict_proba(X_test)[:, 1]  # Probability of failure (class 1)

# %%
# Build ANN model
ann_model = Sequential([
    Dense(128, input_dim=X_train.shape[1], activation=LeakyReLU()),
    Dense(64, activation=LeakyReLU()),
    Dense(32, activation=LeakyReLU()),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile ANN model
ann_model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
# Early stopping to prevent overfitting
earlystopper = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

# %%
# Train ANN model
ann_model.fit(X_train, y_train, epochs=100, batch_size=128, validation_split=0.20, callbacks=[earlystopper], verbose=1)
# Out:
# Epoch 1/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6893 - loss: 0.6119 - val_accuracy: 0.8973 - val_loss: 0.4021
# Epoch 2/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9151 - loss: 0.3574 - val_accuracy: 0.9270 - val_loss: 0.2708
# Epoch 3/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9324 - loss: 0.2453 - val_accuracy: 0.9388 - val_loss: 0.2023
# Epoch 4/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9421 - loss: 0.1853 - val_accuracy: 0.9506 - val_loss: 0.1559
# Epoch 5/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.1436 - val_accuracy: 0.9621 - val_loss: 0.1272
# Epoch 6/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9634 - loss: 0.1186 - val_accuracy: 0.9643 - val_loss: 0.1072
# Epoch 7/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9661 - loss: 0.0994 - val_accuracy: 0.9676 - val_loss: 0.0939
# Epoch 8/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9700 - loss: 0.0854 - val_accuracy: 0.9685 - val_loss: 0.0852
# Epoch 9/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9710 - loss: 0.0793 - val_accuracy: 0.9694 - val_loss: 0.0787
# Epoch 10/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9717 - loss: 0.0756 - val_accuracy: 0.9676 - val_loss: 0.0750
# Epoch 11/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9703 - loss: 0.0729 - val_accuracy: 0.9703 - val_loss: 0.0707
# Epoch 12/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9704 - loss: 0.0718 - val_accuracy: 0.9700 - val_loss: 0.0691
# Epoch 13/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9716 - loss: 0.0668 - val_accuracy: 0.9727 - val_loss: 0.0664
# Epoch 14/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9717 - loss: 0.0654 - val_accuracy: 0.9736 - val_loss: 0.0652
# Epoch 15/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0629 - val_accuracy: 0.9709 - val_loss: 0.0650
# Epoch 16/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9700 - loss: 0.0646 - val_accuracy: 0.9746 - val_loss: 0.0642
# Epoch 17/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9751 - loss: 0.0609 - val_accuracy: 0.9736 - val_loss: 0.0626
# Epoch 18/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9740 - loss: 0.0641 - val_accuracy: 0.9715 - val_loss: 0.0619
# Epoch 19/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9750 - loss: 0.0600 - val_accuracy: 0.9718 - val_loss: 0.0609
# Epoch 20/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9741 - loss: 0.0602 - val_accuracy: 0.9721 - val_loss: 0.0622
# Epoch 21/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9742 - loss: 0.0600 - val_accuracy: 0.9758 - val_loss: 0.0603
# Epoch 22/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9729 - loss: 0.0623 - val_accuracy: 0.9736 - val_loss: 0.0599
# Epoch 23/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9750 - loss: 0.0606 - val_accuracy: 0.9743 - val_loss: 0.0596
# Epoch 24/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9731 - loss: 0.0597 - val_accuracy: 0.9755 - val_loss: 0.0604
# Epoch 25/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9748 - loss: 0.0582 - val_accuracy: 0.9749 - val_loss: 0.0604
# Epoch 26/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9742 - loss: 0.0595 - val_accuracy: 0.9746 - val_loss: 0.0601
# Epoch 27/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9751 - loss: 0.0594 - val_accuracy: 0.9746 - val_loss: 0.0602
# Epoch 28/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9762 - loss: 0.0588 - val_accuracy: 0.9761 - val_loss: 0.0588
# Epoch 29/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9728 - loss: 0.0631 - val_accuracy: 0.9755 - val_loss: 0.0593
# Epoch 30/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9742 - loss: 0.0613 - val_accuracy: 0.9755 - val_loss: 0.0587
# Epoch 31/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0569 - val_accuracy: 0.9755 - val_loss: 0.0584
# Epoch 32/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9745 - loss: 0.0597 - val_accuracy: 0.9749 - val_loss: 0.0584
# Epoch 33/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9731 - loss: 0.0593 - val_accuracy: 0.9749 - val_loss: 0.0590
# Epoch 34/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9752 - loss: 0.0601 - val_accuracy: 0.9743 - val_loss: 0.0584
# Epoch 35/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9767 - loss: 0.0563 - val_accuracy: 0.9733 - val_loss: 0.0599
# Epoch 36/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9751 - loss: 0.0607 - val_accuracy: 0.9755 - val_loss: 0.0581
# Epoch 37/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9749 - loss: 0.0571 - val_accuracy: 0.9743 - val_loss: 0.0583
# Epoch 38/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9756 - loss: 0.0561 - val_accuracy: 0.9739 - val_loss: 0.0590
# Epoch 39/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9758 - loss: 0.0575 - val_accuracy: 0.9746 - val_loss: 0.0581
# Epoch 40/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.0532 - val_accuracy: 0.9743 - val_loss: 0.0584
# Epoch 41/100
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9772 - loss: 0.0555 - val_accuracy: 0.9736 - val_loss: 0.0593
# Epoch 41: early stopping

# %%
# Get ANN predictions
ann_preds = ann_model.predict(X_test).flatten()
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# ===== Stacking Ensemble (Meta-Classifier) =====
# Combine predictions from RF and ANN as new features
import numpy as np
ensemble_X_train = np.column_stack((rf_model.predict_proba(X_train)[:, 1], ann_model.predict(X_train).flatten()))
ensemble_X_test = np.column_stack((rf_preds, ann_preds))
# Out:
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Train meta-classifier (Logistic Regression)
from sklearn.linear_model import LogisticRegression
meta_classifier = LogisticRegression()
meta_classifier.fit(ensemble_X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Final ensemble predictions
ensemble_preds = meta_classifier.predict(ensemble_X_test)

# %%
# ===== Evaluation =====
print("Accuracy:", metrics.accuracy_score(y_test, ensemble_preds))
print("Precision:", metrics.precision_score(y_test, ensemble_preds))
print("Recall:", metrics.recall_score(y_test, ensemble_preds))
print("F1 Score:", metrics.f1_score(y_test, ensemble_preds))
# Out:
# Accuracy: 0.9777077780470075
# Precision: 0.8774928774928775
# Recall: 0.8627450980392157
# F1 Score: 0.8700564971751412

# %%
# Confusion Matrix
matrix = metrics.confusion_matrix(y_test, ensemble_preds)
sns.heatmap(matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Normal", "Failure"], yticklabels=["Normal", "Failure"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Ensemble Model")
plt.show()

# %% [markdown]
# **Ships**

# %%
df=pd.read_csv('/content/data.csv')

# %%
df.head(11)
# Out:
#     index  Lever position   Ship speed (v)   \
# 0       0            1.138                3
# 1       1            2.088                6
# 2       2            3.144                9
# 3       3            4.161               12
# 4       4            5.140               15
# 5       5            6.175               18
# 6       6            7.148               21
# 7       7            8.206               24
# 8       8            9.300               27
# 9       9            1.138                3
# 10     10            2.088                6
#
#     Gas Turbine (GT) shaft torque (GTT) [kN m]    \
# 0                                        289.964
# 1                                       6960.180
# 2                                       8379.229
# 3                                      14724.395
# 4                                      21636.432
# 5                                      29792.731
# 6                                      38982.180
# 7                                      50996.808
# 8                                      72763.329
# 9                                        379.880
# 10                                      6969.176
#
#     GT rate of revolutions (GTn) [rpm]    \
# 0                               1349.489
# 1                               1376.166
# 2                               1386.757
# 3                               1547.465
# 4                               1924.313
# 5                               2307.404
# 6                               2678.086
# 7                               3087.561
# 8                               3560.395
# 9                               1355.375
# 10                              1371.940
#
#     Gas Generator rate of revolutions (GGn) [rpm]    \
# 0                                          6677.380
# 1                                          6828.469
# 2                                          7111.811
# 3                                          7792.630
# 4                                          8494.777
# 5                                          8828.360
# 6                                          9132.429
# 7                                          9318.562
# 8                                          9778.528
# 9                                          6683.916
# 10                                         6828.438
#
#     Starboard Propeller Torque (Ts) [kN]    Port Propeller Torque (Tp) [kN]    \
# 0                                    7.584                              7.584
# 1                                   28.204                             28.204
# 2                                   60.358                             60.358
# 3                                  113.774                            113.774
# 4                                  175.306                            175.306
# 5                                  246.278                            246.278
# 6                                  332.077                            332.077
# 7                                  437.989                            437.989
# 8                                  644.905                            644.905
# 9                                    7.915                              7.915
# 10                                  27.424                             27.424
#
#     Hight Pressure (HP) Turbine exit temperature (T48) [C]    \
# 0                                             464.006
# 1                                             635.401
# 2                                             606.002
# 3                                             661.471
# 4                                             731.494
# 5                                             800.434
# 6                                             854.747
# 7                                             952.122
# 8                                            1115.797
# 9                                             464.017
# 10                                            635.960
#
#     GT Compressor inlet air temperature (T1) [C]    \
# 0                                              288
# 1                                              288
# 2                                              288
# 3                                              288
# 4                                              288
# 5                                              288
# 6                                              288
# 7                                              288
# 8                                              288
# 9                                              288
# 10                                             288
#
#     GT Compressor outlet air temperature (T2) [C]    \
# 0                                           550.563
# 1                                           581.658
# 2                                           587.587
# 3                                           613.851
# 4                                           645.642
# 5                                           676.397
# 6                                           699.954
# 7                                           741.770
# 8                                           789.094
# 9                                           550.985
# 10                                          581.440
#
#     HP Turbine exit pressure (P48) [bar]    \
# 0                                    1.096
# 1                                    1.331
# 2                                    1.389
# 3                                    1.658
# 4                                    2.078
# 5                                    2.501
# 6                                    2.963
# 7                                    3.576
# 8                                    4.498
# 9                                    1.100
# 10                                   1.330
#
#     GT Compressor inlet air pressure (P1) [bar]    \
# 0                                           0.998
# 1                                           0.998
# 2                                           0.998
# 3                                           0.998
# 4                                           0.998
# 5                                           0.998
# 6                                           0.998
# 7                                           0.998
# 8                                           0.998
# 9                                           0.998
# 10                                          0.998
#
#     GT Compressor outlet air pressure (P2) [bar]    \
# 0                                            5.947
# 1                                            7.282
# 2                                            7.574
# 3                                            9.007
# 4                                           11.197
# 5                                           13.356
# 6                                           15.679
# 7                                           18.632
# 8                                           22.811
# 9                                            5.963
# 10                                           7.272
#
#     GT exhaust gas pressure (Pexh) [bar]    \
# 0                                    1.019
# 1                                    1.019
# 2                                    1.020
# 3                                    1.022
# 4                                    1.026
# 5                                    1.030
# 6                                    1.035
# 7                                    1.040
# 8                                    1.049
# 9                                    1.019
# 10                                   1.019
#
#     Turbine Injecton Control (TIC) [%]    Fuel flow (mf) [kg/s]    \
# 0                                  7.137                    0.082
# 1                                 10.655                    0.287
# 2                                 13.086                    0.259
# 3                                 18.109                    0.358
# 4                                 26.373                    0.522
# 5                                 35.760                    0.708
# 6                                 45.881                    0.908
# 7                                 62.440                    1.236
# 8                                 92.556                    1.832
# 9                                  3.879                    0.079
# 10                                12.785                    0.289
#
#     GT Compressor decay state coefficient    \
# 0                                      0.95
# 1                                      0.95
# 2                                      0.95
# 3                                      0.95
# 4                                      0.95
# 5                                      0.95
# 6                                      0.95
# 7                                      0.95
# 8                                      0.95
# 9                                      0.95
# 10                                     0.95
#
#     GT Turbine decay state coefficient
# 0                                 0.975
# 1                                 0.975
# 2                                 0.975
# 3                                 0.975
# 4                                 0.975
# 5                                 0.975
# 6                                 0.975
# 7                                 0.975
# 8                                 0.975
# 9                                 0.976
# 10                                0.976

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 19 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   index                                                     11934 non-null  int64
#  1   Lever position                                            11934 non-null  float64
#  2   Ship speed (v)                                            11934 non-null  int64
#  3   Gas Turbine (GT) shaft torque (GTT) [kN m]                11934 non-null  float64
#  4   GT rate of revolutions (GTn) [rpm]                        11934 non-null  float64
#  5   Gas Generator rate of revolutions (GGn) [rpm]             11934 non-null  float64
#  6   Starboard Propeller Torque (Ts) [kN]                      11934 non-null  float64
#  7   Port Propeller Torque (Tp) [kN]                           11934 non-null  float64
#  8   Hight Pressure (HP) Turbine exit temperature (T48) [C]    11934 non-null  float64
#  9   GT Compressor inlet air temperature (T1) [C]              11934 non-null  int64
#  10  GT Compressor outlet air temperature (T2) [C]             11934 non-null  float64
#  11  HP Turbine exit pressure (P48) [bar]                      11934 non-null  float64
#  12  GT Compressor inlet air pressure (P1) [bar]               11934 non-null  float64
#  13  GT Compressor outlet air pressure (P2) [bar]              11934 non-null  float64
#  14  GT exhaust gas pressure (Pexh) [bar]                      11934 non-null  float64
#  15  Turbine Injecton Control (TIC) [%]                        11934 non-null  float64
#  16  Fuel flow (mf) [kg/s]                                     11934 non-null  float64
#  17  GT Compressor decay state coefficient                     11934 non-null  float64
#  18  GT Turbine decay state coefficient                        11934 non-null  float64
# dtypes: float64(16), int64(3)
# memory usage: 1.7 MB

# %%
df.shape
# Out:
# (11934, 19)

# %%
df= df.drop("index",axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 18 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Lever position                                            11934 non-null  float64
#  1   Ship speed (v)                                            11934 non-null  int64
#  2   Gas Turbine (GT) shaft torque (GTT) [kN m]                11934 non-null  float64
#  3   GT rate of revolutions (GTn) [rpm]                        11934 non-null  float64
#  4   Gas Generator rate of revolutions (GGn) [rpm]             11934 non-null  float64
#  5   Starboard Propeller Torque (Ts) [kN]                      11934 non-null  float64
#  6   Port Propeller Torque (Tp) [kN]                           11934 non-null  float64
#  7   Hight Pressure (HP) Turbine exit temperature (T48) [C]    11934 non-null  float64
#  8   GT Compressor inlet air temperature (T1) [C]              11934 non-null  int64
#  9   GT Compressor outlet air temperature (T2) [C]             11934 non-null  float64
#  10  HP Turbine exit pressure (P48) [bar]                      11934 non-null  float64
#  11  GT Compressor inlet air pressure (P1) [bar]               11934 non-null  float64
#  12  GT Compressor outlet air pressure (P2) [bar]              11934 non-null  float64
#  13  GT exhaust gas pressure (Pexh) [bar]                      11934 non-null  float64
#  14  Turbine Injecton Control (TIC) [%]                        11934 non-null  float64
#  15  Fuel flow (mf) [kg/s]                                     11934 non-null  float64
#  16  GT Compressor decay state coefficient                     11934 non-null  float64
#  17  GT Turbine decay state coefficient                        11934 non-null  float64
# dtypes: float64(16), int64(2)
# memory usage: 1.6 MB

# %%
df.isnull().sum()
# Out:
# Lever position                                              0
# Ship speed (v)                                              0
# Gas Turbine (GT) shaft torque (GTT) [kN m]                  0
# GT rate of revolutions (GTn) [rpm]                          0
# Gas Generator rate of revolutions (GGn) [rpm]               0
# Starboard Propeller Torque (Ts) [kN]                        0
# Port Propeller Torque (Tp) [kN]                             0
# Hight Pressure (HP) Turbine exit temperature (T48) [C]      0
# GT Compressor inlet air temperature (T1) [C]                0
# GT Compressor outlet air temperature (T2) [C]               0
# HP Turbine exit pressure (P48) [bar]                        0
# GT Compressor inlet air pressure (P1) [bar]                 0
# GT Compressor outlet air pressure (P2) [bar]                0
# GT exhaust gas pressure (Pexh) [bar]                        0
# Turbine Injecton Control (TIC) [%]                          0
# Fuel flow (mf) [kg/s]                                       0
# GT Compressor decay state coefficient                       0
# GT Turbine decay state coefficient                          0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        Lever position   Ship speed (v)   \
# 0                1.138                3
# 1                2.088                6
# 2                3.144                9
# 3                4.161               12
# 4                5.140               15
# ...                ...              ...
# 11929            5.140               15
# 11930            6.175               18
# 11931            7.148               21
# 11932            8.206               24
# 11933            9.300               27
#
#        Gas Turbine (GT) shaft torque (GTT) [kN m]    \
# 0                                           289.964
# 1                                          6960.180
# 2                                          8379.229
# 3                                         14724.395
# 4                                         21636.432
# ...                                             ...
# 11929                                     21624.934
# 11930                                     29763.213
# 11931                                     39003.867
# 11932                                     50992.579
# 11933                                     72775.130
#
#        GT rate of revolutions (GTn) [rpm]    \
# 0                                  1349.489
# 1                                  1376.166
# 2                                  1386.757
# 3                                  1547.465
# 4                                  1924.313
# ...                                     ...
# 11929                              1924.342
# 11930                              2306.745
# 11931                              2678.052
# 11932                              3087.434
# 11933                              3560.400
#
#        Gas Generator rate of revolutions (GGn) [rpm]    \
# 0                                             6677.380
# 1                                             6828.469
# 2                                             7111.811
# 3                                             7792.630
# 4                                             8494.777
# ...                                                ...
# 11929                                         8470.013
# 11930                                         8800.352
# 11931                                         9120.889
# 11932                                         9300.274
# 11933                                         9742.950
#
#        Starboard Propeller Torque (Ts) [kN]    \
# 0                                       7.584
# 1                                      28.204
# 2                                      60.358
# 3                                     113.774
# 4                                     175.306
# ...                                       ...
# 11929                                 175.239
# 11930                                 245.954
# 11931                                 332.389
# 11932                                 438.024
# 11933                                 644.880
#
#        Port Propeller Torque (Tp) [kN]    \
# 0                                  7.584
# 1                                 28.204
# 2                                 60.358
# 3                                113.774
# 4                                175.306
# ...                                  ...
# 11929                            175.239
# 11930                            245.954
# 11931                            332.389
# 11932                            438.024
# 11933                            644.880
#
#        Hight Pressure (HP) Turbine exit temperature (T48) [C]    \
# 0                                                464.006
# 1                                                635.401
# 2                                                606.002
# 3                                                661.471
# 4                                                731.494
# ...                                                  ...
# 11929                                            681.658
# 11930                                            747.405
# 11931                                            796.457
# 11932                                            892.945
# 11933                                           1038.411
#
#        GT Compressor inlet air temperature (T1) [C]    \
# 0                                                 288
# 1                                                 288
# 2                                                 288
# 3                                                 288
# 4                                                 288
# ...                                               ...
# 11929                                             288
# 11930                                             288
# 11931                                             288
# 11932                                             288
# 11933                                             288
#
#        GT Compressor outlet air temperature (T2) [C]    \
# 0                                              550.563
# 1                                              581.658
# 2                                              587.587
# 3                                              613.851
# 4                                              645.642
# ...                                                ...
# 11929                                          628.950
# 11930                                          658.853
# 11931                                          680.393
# 11932                                          722.029
# 11933                                          767.595
#
#        HP Turbine exit pressure (P48) [bar]    \
# 0                                       1.096
# 1                                       1.331
# 2                                       1.389
# 3                                       1.658
# 4                                       2.078
# ...                                       ...
# 11929                                   2.087
# 11930                                   2.512
# 11931                                   2.982
# 11932                                   3.594
# 11933                                   4.531
#
#        GT Compressor inlet air pressure (P1) [bar]    \
# 0                                              0.998
# 1                                              0.998
# 2                                              0.998
# 3                                              0.998
# 4                                              0.998
# ...                                              ...
# 11929                                          0.998
# 11930                                          0.998
# 11931                                          0.998
# 11932                                          0.998
# 11933                                          0.998
#
#        GT Compressor outlet air pressure (P2) [bar]    \
# 0                                               5.947
# 1                                               7.282
# 2                                               7.574
# 3                                               9.007
# 4                                              11.197
# ...                                               ...
# 11929                                          10.990
# 11930                                          13.109
# 11931                                          15.420
# 11932                                          18.293
# 11933                                          22.464
#
#        GT exhaust gas pressure (Pexh) [bar]    \
# 0                                       1.019
# 1                                       1.019
# 2                                       1.020
# 3                                       1.022
# 4                                       1.026
# ...                                       ...
# 11929                                   1.027
# 11930                                   1.031
# 11931                                   1.036
# 11932                                   1.043
# 11933                                   1.052
#
#        Turbine Injecton Control (TIC) [%]    Fuel flow (mf) [kg/s]    \
# 0                                     7.137                    0.082
# 1                                    10.655                    0.287
# 2                                    13.086                    0.259
# 3                                    18.109                    0.358
# 4                                    26.373                    0.522
# ...                                     ...                      ...
# 11929                                23.803                    0.471
# 11930                                32.671                    0.647
# 11931                                42.104                    0.834
# 11932                                58.064                    1.149
# 11933                                86.067                    1.704
#
#        GT Compressor decay state coefficient    \
# 0                                         0.95
# 1                                         0.95
# 2                                         0.95
# 3                                         0.95
# 4                                         0.95
# ...                                        ...
# 11929                                     1.00
# 11930                                     1.00
# 11931                                     1.00
# 11932                                     1.00
# 11933                                     1.00
#
#        GT Turbine decay state coefficient
# 0                                    0.975
# 1                                    0.975
# 2                                    0.975
# 3                                    0.975
# 4                                    0.975
# ...                                    ...
# 11929                                1.000
# 11930                                1.000
# 11931                                1.000
# 11932                                1.000
# 11933                                1.000
#
# [11934 rows x 18 columns]

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]=enc.fit_transform(df[i])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11934 entries, 0 to 11933
# Data columns (total 18 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Lever position                                            11934 non-null  float64
#  1   Ship speed (v)                                            11934 non-null  int64
#  2   Gas Turbine (GT) shaft torque (GTT) [kN m]                11934 non-null  float64
#  3   GT rate of revolutions (GTn) [rpm]                        11934 non-null  float64
#  4   Gas Generator rate of revolutions (GGn) [rpm]             11934 non-null  float64
#  5   Starboard Propeller Torque (Ts) [kN]                      11934 non-null  float64
#  6   Port Propeller Torque (Tp) [kN]                           11934 non-null  float64
#  7   Hight Pressure (HP) Turbine exit temperature (T48) [C]    11934 non-null  float64
#  8   GT Compressor inlet air temperature (T1) [C]              11934 non-null  int64
#  9   GT Compressor outlet air temperature (T2) [C]             11934 non-null  float64
#  10  HP Turbine exit pressure (P48) [bar]                      11934 non-null  float64
#  11  GT Compressor inlet air pressure (P1) [bar]               11934 non-null  float64
#  12  GT Compressor outlet air pressure (P2) [bar]              11934 non-null  float64
#  13  GT exhaust gas pressure (Pexh) [bar]                      11934 non-null  float64
#  14  Turbine Injecton Control (TIC) [%]                        11934 non-null  float64
#  15  Fuel flow (mf) [kg/s]                                     11934 non-null  float64
#  16  GT Compressor decay state coefficient                     11934 non-null  float64
#  17  GT Turbine decay state coefficient                        11934 non-null  float64
# dtypes: float64(16), int64(2)
# memory usage: 1.6 MB

# %%
dataplot=sns.heatmap(df.corr())
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['Lever position ', 'Ship speed (v) ',
#        'Gas Turbine (GT) shaft torque (GTT) [kN m]  ',
#        'GT rate of revolutions (GTn) [rpm]  ',
#        'Gas Generator rate of revolutions (GGn) [rpm]  ',
#        'Starboard Propeller Torque (Ts) [kN]  ',
#        'Port Propeller Torque (Tp) [kN]  ',
#        'Hight Pressure (HP) Turbine exit temperature (T48) [C]  ',
#        'GT Compressor inlet air temperature (T1) [C]  ',
#        'GT Compressor outlet air temperature (T2) [C]  ',
#        'HP Turbine exit pressure (P48) [bar]  ',
#        'GT Compressor inlet air pressure (P1) [bar]  ',
#        'GT Compressor outlet air pressure (P2) [bar]  ',
#        'GT exhaust gas pressure (Pexh) [bar]  ',
#        'Turbine Injecton Control (TIC) [%]  ', 'Fuel flow (mf) [kg/s]  ',
#        'GT Compressor decay state coefficient  ',
#        'GT Turbine decay state coefficient '],
#       dtype='object')

# %%
df.columns=['Lever position ', 'Ship speed (v) ',
       'Gas Turbine (GT) shaft torque (GTT) [kN m]  ',
       'GT rate of revolutions (GTn) [rpm]  ',
       'Gas Generator rate of revolutions (GGn) [rpm]  ',
       'Starboard Propeller Torque (Ts) [kN]  ',
       'Port Propeller Torque (Tp) [kN]  ',
       'Hight Pressure (HP) Turbine exit temperature (T48) [C]  ',
       'GT Compressor inlet air temperature (T1) [C]  ',
       'GT Compressor outlet air temperature (T2) [C]  ',
       'HP Turbine exit pressure (P48) [bar]  ',
       'GT Compressor inlet air pressure (P1) [bar]  ',
       'GT Compressor outlet air pressure (P2) [bar]  ',
       'GT exhaust gas pressure (Pexh) [bar]  ',
       'Turbine Injecton Control (TIC) [%]  ', 'Fuel flow (mf) [kg/s]  ','compressor decay','turbine decay']

# %%
y=df.loc[:,["compressor decay","turbine decay",]]
x=df.drop(['compressor decay','turbine decay'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
scaler = StandardScaler()
x = scaler.fit_transform(x)
x = Normalizer().fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.20)
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (9547, 16) (9547, 2) (2387, 16) (2387, 2)

# %%
# !pip install tensorflow
import tensorflow as tf # Import tensorflow
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from sklearn import metrics
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Compute class weights to address potential class imbalance
class_weights = compute_class_weight('balanced', classes=np.unique(y_train.values.argmax(axis=1)), y=y_train.values.argmax(axis=1))
class_weights = dict(enumerate(class_weights))

# Define the ANN model
model = Sequential([
    Dense(256, activation='relu', input_shape=(x_train.shape[1],), kernel_regularizer=tf.keras.regularizers.l2(0.01)), # Use tf alias here
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),# Use tf alias here
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),# Use tf alias here
    BatchNormalization(),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile the model with adjusted learning rate and loss function
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy']) # Use tf alias here

# Define callbacks
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.001 * 0.9**epoch) # Use tf alias here
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True) # Use tf alias here


# Train the model with class weights
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2, class_weight=class_weights, verbose=1, callbacks=[lr_scheduler, early_stopping])

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4965 - loss: 4.0106 - val_accuracy: 0.4817 - val_loss: 2.8046 - learning_rate: 0.0010
# Epoch 2/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5223 - loss: 2.7682 - val_accuracy: 0.2670 - val_loss: 2.6077 - learning_rate: 9.0000e-04
# Epoch 3/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5718 - loss: 2.5664 - val_accuracy: 0.2712 - val_loss: 2.5421 - learning_rate: 8.1000e-04
# Epoch 4/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5836 - loss: 2.5556 - val_accuracy: 0.3901 - val_loss: 2.5376 - learning_rate: 7.2900e-04
# Epoch 5/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5693 - loss: 2.5481 - val_accuracy: 0.5759 - val_loss: 2.5353 - learning_rate: 6.5610e-04
# Epoch 6/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5812 - loss: 2.5416 - val_accuracy: 0.5005 - val_loss: 2.5326 - learning_rate: 5.9049e-04
# Epoch 7/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5823 - loss: 2.5361 - val_accuracy: 0.6136 - val_loss: 2.5329 - learning_rate: 5.3144e-04
# Epoch 8/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5691 - loss: 2.5425 - val_accuracy: 0.6937 - val_loss: 2.5151 - learning_rate: 4.7830e-04
# Epoch 9/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5554 - loss: 2.5403 - val_accuracy: 0.6288 - val_loss: 2.5098 - learning_rate: 4.3047e-04
# Epoch 10/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5743 - loss: 2.5161 - val_accuracy: 0.6314 - val_loss: 2.5037 - learning_rate: 3.8742e-04
# Epoch 11/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5734 - loss: 2.5086 - val_accuracy: 0.6476 - val_loss: 2.4911 - learning_rate: 3.4868e-04
# Epoch 12/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5690 - loss: 2.5063 - val_accuracy: 0.5560 - val_loss: 2.4887 - learning_rate: 3.1381e-04
# Epoch 13/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5687 - loss: 2.5050 - val_accuracy: 0.5958 - val_loss: 2.4849 - learning_rate: 2.8243e-04
# Epoch 14/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5601 - loss: 2.4908 - val_accuracy: 0.5791 - val_loss: 2.4748 - learning_rate: 2.5419e-04
# Epoch 15/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5666 - loss: 2.4821 - val_accuracy: 0.5901 - val_loss: 2.4675 - learning_rate: 2.2877e-04
# Epoch 16/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5669 - loss: 2.4862 - val_accuracy: 0.6471 - val_loss: 2.4580 - learning_rate: 2.0589e-04
# Epoch 17/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5655 - loss: 2.4752 - val_accuracy: 0.5969 - val_loss: 2.4532 - learning_rate: 1.8530e-04
# Epoch 18/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5666 - loss: 2.4679 - val_accuracy: 0.6152 - val_loss: 2.4472 - learning_rate: 1.6677e-04
# Epoch 19/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5637 - loss: 2.4524 - val_accuracy: 0.4953 - val_loss: 2.4422 - learning_rate: 1.5009e-04
# Epoch 20/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5598 - loss: 2.4660 - val_accuracy: 0.6476 - val_loss: 2.4368 - learning_rate: 1.3509e-04
# Epoch 21/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5632 - loss: 2.4692 - val_accuracy: 0.6607 - val_loss: 2.4324 - learning_rate: 1.2158e-04
# Epoch 22/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5592 - loss: 2.4689 - val_accuracy: 0.6649 - val_loss: 2.4289 - learning_rate: 1.0942e-04
# Epoch 23/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5629 - loss: 2.4453 - val_accuracy: 0.5969 - val_loss: 2.4260 - learning_rate: 9.8477e-05
# Epoch 24/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5608 - loss: 2.4602 - val_accuracy: 0.6571 - val_loss: 2.4209 - learning_rate: 8.8629e-05
# Epoch 25/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5627 - loss: 2.4353 - val_accuracy: 0.6047 - val_loss: 2.4183 - learning_rate: 7.9766e-05
# Epoch 26/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5508 - loss: 2.4576 - val_accuracy: 0.6775 - val_loss: 2.4154 - learning_rate: 7.1790e-05
# Epoch 27/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5637 - loss: 2.4366 - val_accuracy: 0.6628 - val_loss: 2.4127 - learning_rate: 6.4611e-05
# Epoch 28/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5612 - loss: 2.4503 - val_accuracy: 0.6482 - val_loss: 2.4106 - learning_rate: 5.8150e-05
# Epoch 29/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5545 - loss: 2.4282 - val_accuracy: 0.6283 - val_loss: 2.4075 - learning_rate: 5.2335e-05
# Epoch 30/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5611 - loss: 2.4302 - val_accuracy: 0.6141 - val_loss: 2.4059 - learning_rate: 4.7101e-05
# Epoch 31/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5631 - loss: 2.4358 - val_accuracy: 0.6607 - val_loss: 2.4035 - learning_rate: 4.2391e-05
# Epoch 32/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5694 - loss: 2.4233 - val_accuracy: 0.6550 - val_loss: 2.4013 - learning_rate: 3.8152e-05
# Epoch 33/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5672 - loss: 2.4327 - val_accuracy: 0.6440 - val_loss: 2.3996 - learning_rate: 3.4337e-05
# Epoch 34/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5721 - loss: 2.4275 - val_accuracy: 0.6613 - val_loss: 2.3986 - learning_rate: 3.0903e-05
# Epoch 35/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5591 - loss: 2.4207 - val_accuracy: 0.6618 - val_loss: 2.3966 - learning_rate: 2.7813e-05
# Epoch 36/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5667 - loss: 2.4253 - val_accuracy: 0.6466 - val_loss: 2.3950 - learning_rate: 2.5032e-05
# Epoch 37/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5590 - loss: 2.4316 - val_accuracy: 0.6654 - val_loss: 2.3933 - learning_rate: 2.2528e-05
# Epoch 38/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5502 - loss: 2.4183 - val_accuracy: 0.6518 - val_loss: 2.3915 - learning_rate: 2.0276e-05
# Epoch 39/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5622 - loss: 2.4028 - val_accuracy: 0.6377 - val_loss: 2.3908 - learning_rate: 1.8248e-05
# Epoch 40/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5573 - loss: 2.4252 - val_accuracy: 0.6545 - val_loss: 2.3888 - learning_rate: 1.6423e-05
# Epoch 41/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5642 - loss: 2.4300 - val_accuracy: 0.6723 - val_loss: 2.3880 - learning_rate: 1.4781e-05
# Epoch 42/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5536 - loss: 2.4165 - val_accuracy: 0.6482 - val_loss: 2.3867 - learning_rate: 1.3303e-05
# Epoch 43/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5494 - loss: 2.4219 - val_accuracy: 0.6586 - val_loss: 2.3861 - learning_rate: 1.1973e-05
# Epoch 44/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5630 - loss: 2.4099 - val_accuracy: 0.6387 - val_loss: 2.3848 - learning_rate: 1.0775e-05
# Epoch 45/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5670 - loss: 2.4214 - val_accuracy: 0.6115 - val_loss: 2.3843 - learning_rate: 9.6977e-06
# Epoch 46/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5568 - loss: 2.3925 - val_accuracy: 0.6586 - val_loss: 2.3831 - learning_rate: 8.7280e-06
# Epoch 47/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5620 - loss: 2.4053 - val_accuracy: 0.6670 - val_loss: 2.3826 - learning_rate: 7.8552e-06
# Epoch 48/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5457 - loss: 2.4172 - val_accuracy: 0.6482 - val_loss: 2.3818 - learning_rate: 7.0697e-06
# Epoch 49/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5650 - loss: 2.3977 - val_accuracy: 0.6534 - val_loss: 2.3802 - learning_rate: 6.3627e-06
# Epoch 50/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5565 - loss: 2.3992 - val_accuracy: 0.6335 - val_loss: 2.3800 - learning_rate: 5.7264e-06
# Epoch 51/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5632 - loss: 2.3888 - val_accuracy: 0.6550 - val_loss: 2.3794 - learning_rate: 5.1538e-06
# Epoch 52/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5694 - loss: 2.4131 - val_accuracy: 0.6555 - val_loss: 2.3791 - learning_rate: 4.6384e-06
# Epoch 53/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5590 - loss: 2.4195 - val_accuracy: 0.6382 - val_loss: 2.3782 - learning_rate: 4.1746e-06
# Epoch 54/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5559 - loss: 2.4112 - val_accuracy: 0.6524 - val_loss: 2.3774 - learning_rate: 3.7571e-06
# Epoch 55/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5580 - loss: 2.4085 - val_accuracy: 0.6607 - val_loss: 2.3771 - learning_rate: 3.3814e-06
# Epoch 56/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5549 - loss: 2.4054 - val_accuracy: 0.6539 - val_loss: 2.3761 - learning_rate: 3.0433e-06
# Epoch 57/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5523 - loss: 2.4101 - val_accuracy: 0.6429 - val_loss: 2.3760 - learning_rate: 2.7389e-06
# Epoch 58/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5758 - loss: 2.3992 - val_accuracy: 0.6634 - val_loss: 2.3756 - learning_rate: 2.4650e-06
# Epoch 59/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5583 - loss: 2.4008 - val_accuracy: 0.6393 - val_loss: 2.3754 - learning_rate: 2.2185e-06
# Epoch 60/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5640 - loss: 2.4004 - val_accuracy: 0.6565 - val_loss: 2.3746 - learning_rate: 1.9967e-06
# Epoch 61/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5657 - loss: 2.3982 - val_accuracy: 0.6492 - val_loss: 2.3742 - learning_rate: 1.7970e-06
# Epoch 62/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5645 - loss: 2.4017 - val_accuracy: 0.6581 - val_loss: 2.3739 - learning_rate: 1.6173e-06
# Epoch 63/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5543 - loss: 2.3927 - val_accuracy: 0.6419 - val_loss: 2.3735 - learning_rate: 1.4556e-06
# Epoch 64/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5634 - loss: 2.3915 - val_accuracy: 0.6644 - val_loss: 2.3731 - learning_rate: 1.3100e-06
# Epoch 65/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5514 - loss: 2.3966 - val_accuracy: 0.6560 - val_loss: 2.3734 - learning_rate: 1.1790e-06
# Epoch 66/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5668 - loss: 2.3958 - val_accuracy: 0.6524 - val_loss: 2.3729 - learning_rate: 1.0611e-06
# Epoch 67/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5584 - loss: 2.3848 - val_accuracy: 0.6670 - val_loss: 2.3720 - learning_rate: 9.5500e-07
# Epoch 68/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5562 - loss: 2.4005 - val_accuracy: 0.6545 - val_loss: 2.3724 - learning_rate: 8.5950e-07
# Epoch 69/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5597 - loss: 2.3989 - val_accuracy: 0.6560 - val_loss: 2.3721 - learning_rate: 7.7355e-07
# Epoch 70/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5644 - loss: 2.3963 - val_accuracy: 0.6691 - val_loss: 2.3719 - learning_rate: 6.9620e-07
# Epoch 71/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5707 - loss: 2.4071 - val_accuracy: 0.6539 - val_loss: 2.3721 - learning_rate: 6.2658e-07
# Epoch 72/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5699 - loss: 2.3906 - val_accuracy: 0.6393 - val_loss: 2.3716 - learning_rate: 5.6392e-07
# Epoch 73/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5610 - loss: 2.4033 - val_accuracy: 0.6450 - val_loss: 2.3716 - learning_rate: 5.0753e-07
# Epoch 74/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5680 - loss: 2.4061 - val_accuracy: 0.6665 - val_loss: 2.3712 - learning_rate: 4.5678e-07
# Epoch 75/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5628 - loss: 2.4019 - val_accuracy: 0.6288 - val_loss: 2.3710 - learning_rate: 4.1110e-07
# Epoch 76/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5516 - loss: 2.4136 - val_accuracy: 0.6377 - val_loss: 2.3713 - learning_rate: 3.6999e-07
# Epoch 77/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5650 - loss: 2.3930 - val_accuracy: 0.6602 - val_loss: 2.3710 - learning_rate: 3.3299e-07
# Epoch 78/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5609 - loss: 2.4031 - val_accuracy: 0.6518 - val_loss: 2.3711 - learning_rate: 2.9969e-07
# Epoch 79/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5596 - loss: 2.3942 - val_accuracy: 0.6466 - val_loss: 2.3712 - learning_rate: 2.6972e-07
# Epoch 80/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5521 - loss: 2.3898 - val_accuracy: 0.6723 - val_loss: 2.3708 - learning_rate: 2.4275e-07
# Epoch 81/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5637 - loss: 2.3966 - val_accuracy: 0.6445 - val_loss: 2.3705 - learning_rate: 2.1847e-07
# Epoch 82/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5592 - loss: 2.3983 - val_accuracy: 0.6675 - val_loss: 2.3712 - learning_rate: 1.9663e-07
# Epoch 83/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5560 - loss: 2.3899 - val_accuracy: 0.6429 - val_loss: 2.3709 - learning_rate: 1.7696e-07
# Epoch 84/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5565 - loss: 2.3952 - val_accuracy: 0.6524 - val_loss: 2.3704 - learning_rate: 1.5927e-07
# Epoch 85/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5647 - loss: 2.3945 - val_accuracy: 0.6455 - val_loss: 2.3705 - learning_rate: 1.4334e-07
# Epoch 86/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5624 - loss: 2.3964 - val_accuracy: 0.6613 - val_loss: 2.3702 - learning_rate: 1.2901e-07
# Epoch 87/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5621 - loss: 2.3887 - val_accuracy: 0.6963 - val_loss: 2.3705 - learning_rate: 1.1611e-07
# Epoch 88/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5567 - loss: 2.4067 - val_accuracy: 0.6649 - val_loss: 2.3703 - learning_rate: 1.0450e-07
# Epoch 89/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5704 - loss: 2.3804 - val_accuracy: 0.6822 - val_loss: 2.3704 - learning_rate: 9.4046e-08
# Epoch 90/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5556 - loss: 2.3987 - val_accuracy: 0.6455 - val_loss: 2.3704 - learning_rate: 8.4641e-08
# Epoch 91/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5706 - loss: 2.3842 - val_accuracy: 0.6487 - val_loss: 2.3699 - learning_rate: 7.6177e-08
# Epoch 92/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5651 - loss: 2.3943 - val_accuracy: 0.6529 - val_loss: 2.3704 - learning_rate: 6.8560e-08
# Epoch 93/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5560 - loss: 2.3805 - val_accuracy: 0.6450 - val_loss: 2.3701 - learning_rate: 6.1704e-08
# Epoch 94/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5725 - loss: 2.3880 - val_accuracy: 0.6565 - val_loss: 2.3702 - learning_rate: 5.5533e-08
# Epoch 95/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5561 - loss: 2.4002 - val_accuracy: 0.6660 - val_loss: 2.3704 - learning_rate: 4.9980e-08
# Epoch 96/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5565 - loss: 2.3845 - val_accuracy: 0.6487 - val_loss: 2.3703 - learning_rate: 4.4982e-08
# Epoch 97/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5654 - loss: 2.3852 - val_accuracy: 0.6529 - val_loss: 2.3703 - learning_rate: 4.0484e-08
# Epoch 98/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5521 - loss: 2.4067 - val_accuracy: 0.6592 - val_loss: 2.3704 - learning_rate: 3.6435e-08
# Epoch 99/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5673 - loss: 2.3932 - val_accuracy: 0.6445 - val_loss: 2.3703 - learning_rate: 3.2792e-08
# Epoch 100/100
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5593 - loss: 2.3978 - val_accuracy: 0.6560 - val_loss: 2.3701 - learning_rate: 2.9513e-08
# Test Loss: 2.3692984580993652, Test Accuracy: 0.6501885056495667

# %%
# Make predictions
y_pred = model.predict(x_test)

# Predicting test data
y_predict = (y_pred > 0.5).astype('int32')

# Show confusion matrix table
matrix = metrics.confusion_matrix(y_test.values.argmax(axis=1), y_predict.argmax(axis=1))
matrix_display = metrics.ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=["normal", "failure"])
matrix_display.plot()
plt.grid(False)
plt.show()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Calculate accuracy, precision, recall, and F1-score
accuracy = metrics.accuracy_score(y_test.values.argmax(axis=1), y_predict.argmax(axis=1))
precision = metrics.precision_score(y_test.values.argmax(axis=1), y_predict.argmax(axis=1), average='weighted')
recall = metrics.recall_score(y_test.values.argmax(axis=1), y_predict.argmax(axis=1), average='weighted')
f1 = metrics.f1_score(y_test.values.argmax(axis=1), y_predict.argmax(axis=1), average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6519
# Precision: 0.7960
# Recall: 0.6519
# F1 Score: 0.6699

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()
